# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('working_raw_data.csv')

# %%
df.head()
# Out:
#                           PlaceholderID Physics major at one time gndr_flag  \
# 0  4CBAD4C5-7721-4472-AD71-6A7BB0B28F83                         N         F
# 1  72CDD79E-5ECF-4F30-97BC-BAA09731CCED                         N         M
# 2  B9FD0239-0724-4D0D-8125-84C6115F4974                         N         M
# 3  20983455-7A70-487D-848F-8DCE2EAF9CB6                         N         M
# 4  8180BD9F-33C7-45CB-BFA7-A264D1A3E56D                         N         F
#
#   citizenship                                  Ethnicity First Gen  \
# 0  US Citizen                       White (non-Hispanic)         N
# 1  US Citizen                       White (non-Hispanic)         N
# 2  US Citizen  Black or African American  (non-Hispanic)         N
# 3  US Citizen                       White (non-Hispanic)         N
# 4  US Citizen                       White (non-Hispanic)         N
#
#   undergrad Residency first enrolled term at MSU first enrolled level at MSU  \
# ...

# %%
df[df['PlaceholderID']=='72CDD79E-5ECF-4F30-97BC-BAA09731CCED']
# Out:
#                           PlaceholderID Physics major at one time gndr_flag  \
# 1  72CDD79E-5ECF-4F30-97BC-BAA09731CCED                         N         M
#
#   citizenship             Ethnicity First Gen undergrad Residency  \
# 1  US Citizen  White (non-Hispanic)         N            In-State
#
#   first enrolled term at MSU first enrolled level at MSU first UN term at MSU  \
# 1                       FS07          2 - Sophomore (UN)                 FS07
#
#              ...             Transfer most recent UN term (as of SS15)  \
# 1            ...                    Y                             US09
#
#   most recent UN major code     most recent UN major most recent UN level  \
# 1                      3188  International Relations           4 - Senior
#
#    UN grad term (blank if did not graduate)  \
# 1                                      FS09
#
#   UN grad major (blank if did not graduate) First Major Category  \
# ...
